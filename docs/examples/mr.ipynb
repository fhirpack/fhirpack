# %% [markdown]
# # Boilerplate

# %%
# %load_ext autoreload
# %autoreload 2
# %pprint off
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Pretty printing has been turned OFF

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %pprint
# Out:
# Pretty printing has been turned ON

# %% [markdown]
# # Preamble

# %%
import sys,os
sys.path.append(os.getcwd()+'/../src/')

# %% [markdown]
# ### Imports

# %%
import fhirpack	as fp
import pandas	as pd
import numpy	as np
import json

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

RESPATH=f"./data/"

# %% [markdown]
# # FHIR Server Connection

# %% [markdown]
# ## Configure PACK with Environment File

# %%
pack = fp.PACK(envFile='.env.example')

# %% [markdown]
# # MR SAMPLES

# %%
# pack.getPatients(['ddbf5561-4bfd-4434-89fb-344387ca945b'])

# pack.getPatients(
# 	searchParams={
# 		"given":"Muster",
# 		}
# 	)
	
pack.getPatients(['617077'])
# Out:
# GET[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           data  \
# 0  {'resourceType': 'Patient', 'id': '617077', 'meta': {'versionId': '1', 'lastUpdated': '2020-02-07T11:51:46.361+00:00', 'source': '#msg5Ia42NNbn9SQ0'}, 'text': {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295
#  .   Person seed: 516392565305794201  Population seed: 0</div>'}, 'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2135-2', 'display': 'Other'}}, {'url': 'text', 'valueString': 'Other'}]}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2186-5', 'display': 'Not Hispanic or Latino'}}, {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', 'valueString': 'Katrice671 Trantow673'}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex', 'valueCode': 'M'}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace', 'valueAddress': {'city': 'Arlington', 'state': 'Massachusetts', 'country': 'US'}}, {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years', 'valueDecimal': 2.472582883371292}, {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years', 'valueDecimal': 32.527417116628705}], 'identifier': [{'system': 'https://github.com/synthetichealth/synthea', 'value': '611e75ee-bca5-4cb4-9ccd-10f4b98e7732'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'MR', 'display': 'Medical Record Number'}], 'text': 'Medical Record Number'}, 'system': 'http://hospital.smarthealthit.org', 'value': '611e75ee-bca5-4cb4-9ccd-10f4b98e7732'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'SS', 'display': 'Social Security Number'}], 'text': 'Social Security Number'}, 'system': 'http://hl7.org/fhir/sid/us-ssn', 'value': '999-35-3274'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'DL', 'display': "Driver's License"}], 'text': "Driver's License"}, 'system': 'urn:oid:2.16.840.1.113883.4.3.25', 'value': 'S99988297'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'PPN', 'display': 'Passport Number'}], 'text': 'Passport Number'}, 'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber', 'value': 'X83151742X'}], 'name': [{'use': 'official', 'family': 'Konopelski743', 'given': ['Andres25'], 'prefix': ['Mr.']}], 'telecom': [{'system': 'phone', 'value': '555-327-4170', 'use': 'home'}], 'gender': 'male', 'birthDate': '1975-10-07', 'deceasedDateTime': '2011-08-23T03:47:35-04:00', 'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation', 'extension': [{'url': 'latitude', 'valueDecimal': 42.55085189568567}, {'url': 'longitude', 'valueDecimal': -71.48818076632828}]}], 'line': ['943 Wyman Run Unit 38'], 'city': 'Littleton', 'state': 'Massachusetts', 'country': 'US'}], 'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'M'}], 'text': 'M'}, 'multipleBirthBoolean': False, 'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English'}], 'text': 'English'}}]}
#
#   Patient
# 0  617077

# %%
pack.getPatients(['617077'])\
.getLinkedPatients()\
# .getRootPatients()\
# .getObservations()

# .getLinkedPatients()\
# .getConditions()\
# .getObservations()\
# .getObservations()\

# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# Out:
# GET[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           data  \
# 0  {'resourceType': 'Patient', 'id': '617077', 'meta': {'versionId': '1', 'lastUpdated': '2020-02-07T11:51:46.361+00:00', 'source': '#msg5Ia42NNbn9SQ0'}, 'text': {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295
#  .   Person seed: 516392565305794201  Population seed: 0</div>'}, 'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2135-2', 'display': 'Other'}}, {'url': 'text', 'valueString': 'Other'}]}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'extension': [{'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2186-5', 'display': 'Not Hispanic or Latino'}}, {'url': 'text', 'valueString': 'Not Hispanic or Latino'}]}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', 'valueString': 'Katrice671 Trantow673'}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex', 'valueCode': 'M'}, {'url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace', 'valueAddress': {'city': 'Arlington', 'state': 'Massachusetts', 'country': 'US'}}, {'url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years', 'valueDecimal': 2.472582883371292}, {'url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years', 'valueDecimal': 32.527417116628705}], 'identifier': [{'system': 'https://github.com/synthetichealth/synthea', 'value': '611e75ee-bca5-4cb4-9ccd-10f4b98e7732'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'MR', 'display': 'Medical Record Number'}], 'text': 'Medical Record Number'}, 'system': 'http://hospital.smarthealthit.org', 'value': '611e75ee-bca5-4cb4-9ccd-10f4b98e7732'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'SS', 'display': 'Social Security Number'}], 'text': 'Social Security Number'}, 'system': 'http://hl7.org/fhir/sid/us-ssn', 'value': '999-35-3274'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'DL', 'display': "Driver's License"}], 'text': "Driver's License"}, 'system': 'urn:oid:2.16.840.1.113883.4.3.25', 'value': 'S99988297'}, {'type': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'code': 'PPN', 'display': 'Passport Number'}], 'text': 'Passport Number'}, 'system': 'http://standardhealthrecord.org/fhir/StructureDefinition/passportNumber', 'value': 'X83151742X'}], 'name': [{'use': 'official', 'family': 'Konopelski743', 'given': ['Andres25'], 'prefix': ['Mr.']}], 'telecom': [{'system': 'phone', 'value': '555-327-4170', 'use': 'home'}], 'gender': 'male', 'birthDate': '1975-10-07', 'deceasedDateTime': '2011-08-23T03:47:35-04:00', 'address': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/geolocation', 'extension': [{'url': 'latitude', 'valueDecimal': 42.55085189568567}, {'url': 'longitude', 'valueDecimal': -71.48818076632828}]}], 'line': ['943 Wyman Run Unit 38'], 'city': 'Littleton', 'state': 'Massachusetts', 'country': 'US'}], 'maritalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'M'}], 'text': 'M'}, 'multipleBirthBoolean': False, 'communication': [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English'}], 'text': 'English'}}]}
#
#   RootPatient Patient LinkedPatient
# 0      617077  617077        617077

# %%
pack\
.getPatients(['ddbf5561-4bfd-4434-89fb-344387ca945b'])\
.getObservations()\
.getEncounters()
# .summary\
# [:1].pretty
# .getObservations(['fa7a0803-cb87-4af4-ac8c-0216b4e05297'])\
# .getEncounters()\
# .gatherSimplePaths([w'id'])
# .getPatients()\
# .getDiagnosticReports()
# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# Out:
# GET[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# SEARCH[Observation]> : 100%|██████████| 36/36 [00:00<00:00, 51.10it/s]
# SEARCH[Encounter]> : 100%|██████████| 4/4 [00:00<00:00,  5.86it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       data  \
# 0   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 1   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 2   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 3   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 4   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 5   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 6   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 7   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 8   {'resourceType': 'Encounter', 'id': 'e54386bd-dfb9-4030-820b-7e949dda48ff', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '3461000175106', 'display': 'Admitted for observation (finding)'}], 'text': 'Admitted for observation (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-08T08:18:18-05:00', 'end': '2000-07-08T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 9                                  {'resourceType': 'Encounter', 'id': '577d6296-8dba-4a47-9671-1623c711104f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'AMB'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '185347001', 'display': 'Encounter for problem'}], 'text': 'Encounter for problem'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-29T08:18:18-05:00', 'end': '2000-07-29T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 10                                 {'resourceType': 'Encounter', 'id': '577d6296-8dba-4a47-9671-1623c711104f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'AMB'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '185347001', 'display': 'Encounter for problem'}], 'text': 'Encounter for problem'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2000-07-29T08:18:18-05:00', 'end': '2000-07-29T09:18:18-05:00'}, 'reasonCode': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '88805009', 'display': 'Chronic congestive heart failure (disorder)'}]}], 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 11                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 12                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 13                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 14                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 15                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 16                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 17                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 18                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 19                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 20                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 21                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 22                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 23                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 24                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 25                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 26                                                                                                                                                     {'resourceType': 'Encounter', 'id': 'c93eef4f-ed72-47fa-ba72-18bda8931895', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'EMER'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '50849002', 'display': 'Emergency room admission (procedure)'}], 'text': 'Emergency room admission (procedure)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-24T09:48:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 27                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 28                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 29                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 30                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 31                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 32                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 33                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 34                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
# 35                                                                                                                                                                             {'resourceType': 'Encounter', 'id': '8ee5c34e-9b66-47f4-b04f-fb4847cbd49f', 'meta': {'versionId': '1', 'lastUpdated': '2020-03-24T17:54:12.949+00:00', 'source': '#qJi1XIf2IfwL9umc', 'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-encounter'], 'tag': [{'system': 'https://smarthealthit.org/tags', 'code': 'Covid19 synthetic population from Synthea'}]}, 'status': 'finished', 'class': {'system': 'http://terminology.hl7.org/CodeSystem/v3-ActCode', 'code': 'IMP'}, 'type': [{'coding': [{'system': 'http://snomed.info/sct', 'code': '308540004', 'display': 'Inpatient stay (finding)'}], 'text': 'Inpatient stay (finding)'}], 'subject': {'reference': 'Patient/ddbf5561-4bfd-4434-89fb-344387ca945b', 'display': 'Mr. Adam631 Keebler762'}, 'participant': [{'individual': <SyncFHIRReference Practitioner/0000016f-a1db-e77f-0000-0000000002d0>}], 'period': {'start': '2001-07-24T08:18:18-05:00', 'end': '2001-07-25T08:18:18-05:00'}, 'location': [{'location': <SyncFHIRReference Location/46468d2e-d0d8-4354-9711-34446096584f>}], 'serviceProvider': {'reference': 'Organization/7dbe8a71-ceef-3e3e-b99e-fc3d1b5921a1', 'display': 'SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD'}}
#
#                                Encounter  \
# 0   e54386bd-dfb9-4030-820b-7e949dda48ff
# 1   e54386bd-dfb9-4030-820b-7e949dda48ff
# 2   e54386bd-dfb9-4030-820b-7e949dda48ff
# 3   e54386bd-dfb9-4030-820b-7e949dda48ff
# 4   e54386bd-dfb9-4030-820b-7e949dda48ff
# 5   e54386bd-dfb9-4030-820b-7e949dda48ff
# 6   e54386bd-dfb9-4030-820b-7e949dda48ff
# 7   e54386bd-dfb9-4030-820b-7e949dda48ff
# 8   e54386bd-dfb9-4030-820b-7e949dda48ff
# 9   577d6296-8dba-4a47-9671-1623c711104f
# 10  577d6296-8dba-4a47-9671-1623c711104f
# 11  c93eef4f-ed72-47fa-ba72-18bda8931895
# 12  c93eef4f-ed72-47fa-ba72-18bda8931895
# 13  c93eef4f-ed72-47fa-ba72-18bda8931895
# 14  c93eef4f-ed72-47fa-ba72-18bda8931895
# 15  c93eef4f-ed72-47fa-ba72-18bda8931895
# 16  c93eef4f-ed72-47fa-ba72-18bda8931895
# 17  c93eef4f-ed72-47fa-ba72-18bda8931895
# 18  c93eef4f-ed72-47fa-ba72-18bda8931895
# 19  c93eef4f-ed72-47fa-ba72-18bda8931895
# 20  c93eef4f-ed72-47fa-ba72-18bda8931895
# 21  c93eef4f-ed72-47fa-ba72-18bda8931895
# 22  c93eef4f-ed72-47fa-ba72-18bda8931895
# 23  c93eef4f-ed72-47fa-ba72-18bda8931895
# 24  c93eef4f-ed72-47fa-ba72-18bda8931895
# 25  c93eef4f-ed72-47fa-ba72-18bda8931895
# 26  c93eef4f-ed72-47fa-ba72-18bda8931895
# 27  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 28  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 29  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 30  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 31  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 32  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 33  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 34  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
# 35  8ee5c34e-9b66-47f4-b04f-fb4847cbd49f
#
#                              Observation                               Patient
# 0   5bd7ffb0-21ef-49da-b58b-c84191e3820b  ddbf5561-4bfd-4434-89fb-344387ca945b
# 1   94ad7424-8fa6-4a06-b241-e0fb9c6e3f15  ddbf5561-4bfd-4434-89fb-344387ca945b
# 2   4adc56f1-2fbf-40c9-a45a-381b8e0b6bcf  ddbf5561-4bfd-4434-89fb-344387ca945b
# 3   2dcd1f61-6f32-429e-b7b1-9e23e279aacd  ddbf5561-4bfd-4434-89fb-344387ca945b
# 4   19337a93-ed8b-4a05-835d-e6db8c1ed2cd  ddbf5561-4bfd-4434-89fb-344387ca945b
# 5   d9e0b796-ebf2-498e-a242-51a059c56bf6  ddbf5561-4bfd-4434-89fb-344387ca945b
# 6   28ba0a72-a61b-4673-beaf-262eac206845  ddbf5561-4bfd-4434-89fb-344387ca945b
# 7   38c8d31e-5d3f-4da6-989a-e87b98cb2c28  ddbf5561-4bfd-4434-89fb-344387ca945b
# 8   84a46d41-4e45-4d28-bb42-086721c5e170  ddbf5561-4bfd-4434-89fb-344387ca945b
# 9   85478db6-2d52-45e7-b60f-7c69208e270a  ddbf5561-4bfd-4434-89fb-344387ca945b
# 10  3ba0977a-b8b2-4c31-b3f5-8139f0c4470f  ddbf5561-4bfd-4434-89fb-344387ca945b
# 11  01e11055-e19d-4ff5-aea7-cef57c9c54e9  ddbf5561-4bfd-4434-89fb-344387ca945b
# 12  4f4bb63a-b0e1-4754-99ae-135f9bcd8ef1  ddbf5561-4bfd-4434-89fb-344387ca945b
# 13  468ecf9e-3828-4171-a8bd-e3135b324659  ddbf5561-4bfd-4434-89fb-344387ca945b
# 14  183cd525-4cfe-4c63-b3c3-0b22f6ea6441  ddbf5561-4bfd-4434-89fb-344387ca945b
# 15  75356e77-1a94-4cbd-9b28-1c1c14ca22ce  ddbf5561-4bfd-4434-89fb-344387ca945b
# 16  bba53b4b-7776-44eb-90b8-9b8d4b51a841  ddbf5561-4bfd-4434-89fb-344387ca945b
# 17  f7d32c3e-6952-49e0-9d50-d477648eb80f  ddbf5561-4bfd-4434-89fb-344387ca945b
# 18  b9bc57a1-63a4-412d-936d-c9ef150b90c9  ddbf5561-4bfd-4434-89fb-344387ca945b
# 19  b2ce9406-1589-4f49-9887-de935dd58558  ddbf5561-4bfd-4434-89fb-344387ca945b
# 20  b9ab37ff-5520-4f54-9f7c-5ca32b4be976  ddbf5561-4bfd-4434-89fb-344387ca945b
# 21  17fa173c-6786-44e0-bcc7-f6df83319a78  ddbf5561-4bfd-4434-89fb-344387ca945b
# 22  5db94f3d-2394-4866-b76d-f38395d96e9d  ddbf5561-4bfd-4434-89fb-344387ca945b
# 23  6dd96ac6-bc6b-4934-a7d8-3884d73e565c  ddbf5561-4bfd-4434-89fb-344387ca945b
# 24  57502c2e-eb5f-49a9-b160-326963cccc8c  ddbf5561-4bfd-4434-89fb-344387ca945b
# 25  9e8d6cbd-2443-408a-a978-08cc9aff2b2c  ddbf5561-4bfd-4434-89fb-344387ca945b
# 26  31e9ca90-16a9-45bb-b2b2-e770a331eb44  ddbf5561-4bfd-4434-89fb-344387ca945b
# 27  fa7a0803-cb87-4af4-ac8c-0216b4e05297  ddbf5561-4bfd-4434-89fb-344387ca945b
# 28  2badbe0d-6623-464e-b65b-eedc826bdba7  ddbf5561-4bfd-4434-89fb-344387ca945b
# 29  067de220-83a0-44b8-8688-ed614e644721  ddbf5561-4bfd-4434-89fb-344387ca945b
# 30  edeb0c21-5c79-42ca-bdc6-fa1dff9c6f27  ddbf5561-4bfd-4434-89fb-344387ca945b
# 31  94cbbffa-6534-49dd-bcd4-7b8ba8f538f7  ddbf5561-4bfd-4434-89fb-344387ca945b
# 32  78ebb0f8-af09-44a5-bf10-8a549e3a8a64  ddbf5561-4bfd-4434-89fb-344387ca945b
# 33  e72bc49d-4006-4447-892e-44e0ac57f45e  ddbf5561-4bfd-4434-89fb-344387ca945b
# 34  f7027e77-81a4-4c52-acec-cfa6c5b6e10b  ddbf5561-4bfd-4434-89fb-344387ca945b
# 35  2b6c1e4b-838f-4e53-814e-8a24746912cf  ddbf5561-4bfd-4434-89fb-344387ca945b

# %%
a=pd.DataFrame({'col1':[1,3],'col2':[2,4]})
b=pd.DataFrame({'col1':[1,3],'col2':[2,4]})
a
b
a.join(b,on='col1',how='inner',rsuffix='r')
# Out:
#    col1  col2
# 0     1     2
# 1     3     4
#    col1  col2
# 0     1     2
# 1     3     4
#    col1  col2  col1r  col2r
# 0     1     2      3      4

# %%
pack\
.getMedicationAdministrations(['3982400'])\
# .getPatients(['ddbf5561-4bfd-4434-89fb-344387ca945b'])\
# .getPatients()
# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# Out:
# GET[MedicationAdministration]> : 100%|██████████| 1/1 [00:00<00:00,  1.91it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          data  \
# 0  {'resourceType': 'MedicationAdministration', 'id': '3982400', 'meta': {'versionId': '1', 'lastUpdated': '2022-06-23T13:40:38.918+00:00', 'source': '#89dMUNeScdbCSC74'}, 'contained': [{'resourceType': 'Medication', 'id': '1', 'text': {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText"> Testmedication </div></div>'}, 'code': {'coding': [{'system': 'http://hl7.org/fhir/sid/ndc', 'code': '0409-6531-02', 'display': 'Testmedication'}]}}], 'medicationReference': {'reference': '#1'}, 'subject': {'reference': 'Patient/1653', 'display': 'huber'}, 'effectivePeriod': {'start': '2022-06-23T15:40:38.501'}, 'dosage': {'text': '500mg irgendwas', 'method': {'text': 'IV push'}, 'dose': {'value': 500, 'unit': 'mg', 'system': 'http://unitsofmeasure.org', 'code': 'mg'}}}
#
#   MedicationAdministration
# 0                  3982400

# %%
pack\
.getMedicationRequests(['6588523'])\
# .getPatients(['ddbf5561-4bfd-4434-89fb-344387ca945b'])\
# .getPatients()
# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# Out:
# GET[MedicationRequest]> : 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 data  \
# 0  {'resourceType': 'MedicationRequest', 'id': '6588523', 'meta': {'versionId': '1', 'lastUpdated': '2022-07-04T21:15:57.701+00:00', 'source': '#AiG0VwTl6ITfqAnW', 'tag': [{'system': 'http://www.alpha.alp/use-case', 'code': 'EX20ZU'}]}, 'text': {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">
#             <p>Prescription: Amoxicillin 250 MG Oral Capsule</p>
#           </div>'}, 'status': 'stopped', 'intent': 'order', 'medicationReference': {'reference': 'Medication/6588521', 'display': 'Amoxicillin 250 MG Oral Capsule'}, 'subject': {'reference': 'Patient/6588507'}, 'encounter': {'reference': 'Encounter/6588511', 'display': 'Initial encounter'}, 'authoredOn': '2018-06-14', 'requester': {'reference': 'Practitioner/6588508', 'display': 'Dr. Harold Hippocrates'}, 'reasonReference': [{'reference': 'Condition/6588520', 'display': 'Otitis Media'}], 'dosageInstruction': [{'text': '250 mg 3 times per day for 7 days', 'timing': {'repeat': {'boundsDuration': {'value': 7, 'unit': 'day', 'system': 'http://unitsofmeasure.org', 'code': 'd'}, 'frequency': 3, 'period': 1, 'periodUnit': 'd'}}, 'doseAndRate': [{'doseQuantity': {'value': 250, 'unit': 'mg', 'system': 'http://unitsofmeasure.org', 'code': 'mg'}}]}]}
#
#   MedicationRequest
# 0           6588523

# %%
pack\
.getImagingStudies(['2823696'])\
.getPatients()\
# .gatherSimplePaths(['id','birthDate'],columns=['id','birth'])
# Out:
# GET[ImagingStudy]> : 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]
# SEARCH[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
#                                                                                                                                                                                                                                                                        data  \
# 0  {'resourceType': 'Patient', 'id': '2823245', 'meta': {'versionId': '1', 'lastUpdated': '2022-03-01T06:52:42.906+00:00', 'source': '#kLnqpE9Iy6aDGvte'}, 'text': {'status': 'generated', 'div': '<div xmlns="http://www.w3.org/1999/xhtml">#--Patient-empty-1--#</div>'}}
#
#    Patient ImagingStudy
# 0  2823245      2823696

# %%
# fp.PACK("").resourceType

pack.getPatients(['Patient/1555106'])\
	.getObservations()\
	# .gatherSimplePaths(['id'])
# Out:
# GET[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# SEARCH[Observation]> : 100%|██████████| 677/677 [00:06<00:00, 107.34it/s]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  data  \
# 0    {'resourceType': 'Observation', 'id': '1555734', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '6768-6', 'display': 'Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma'}], 'text': 'Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-18T21:53:14-04:00', 'issued': '2020-03-18T21:53:14.197-04:00', 'valueQuantity': {'value': 102.12, 'unit': 'U/L', 'system': 'http://unitsofmeasure.org', 'code': 'U/L'}}
# 1                                                        {'resourceType': 'Observation', 'id': '1555771', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '2885-2', 'display': 'Protein [Mass/volume] in Serum or Plasma'}], 'text': 'Protein [Mass/volume] in Serum or Plasma'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-19T21:53:14-04:00', 'issued': '2020-03-19T21:53:14.197-04:00', 'valueQuantity': {'value': 7.5804, 'unit': 'g/dL', 'system': 'http://unitsofmeasure.org', 'code': 'g/dL'}}
# 2                                       {'resourceType': 'Observation', 'id': '1555770', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '33914-3', 'display': 'Glomerular filtration rate/1.73 sq M.predicted'}], 'text': 'Glomerular filtration rate/1.73 sq M.predicted'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-19T21:53:14-04:00', 'issued': '2020-03-19T21:53:14.197-04:00', 'valueQuantity': {'value': 6.5863, 'unit': 'mL/min', 'system': 'http://unitsofmeasure.org', 'code': 'mL/min'}}
# 3                                                                   {'resourceType': 'Observation', 'id': '1555528', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '785-6', 'display': 'MCH [Entitic mass] by Automated count'}], 'text': 'MCH [Entitic mass] by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-14T21:53:14-04:00', 'issued': '2020-03-14T21:53:14.197-04:00', 'valueQuantity': {'value': 31.211, 'unit': 'pg', 'system': 'http://unitsofmeasure.org', 'code': 'pg'}}
# 4                       {'resourceType': 'Observation', 'id': '1555769', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '2028-9', 'display': 'Carbon dioxide, total [Moles/volume] in Serum or Plasma'}], 'text': 'Carbon dioxide, total [Moles/volume] in Serum or Plasma'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-19T21:53:14-04:00', 'issued': '2020-03-19T21:53:14.197-04:00', 'valueQuantity': {'value': 20.88, 'unit': 'mmol/L', 'system': 'http://unitsofmeasure.org', 'code': 'mmol/L'}}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 672                                     {'resourceType': 'Observation', 'id': '1555806', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '706-2', 'display': 'Basophils/100 leukocytes in Blood by Automated count'}], 'text': 'Basophils/100 leukocytes in Blood by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-20T21:53:14-04:00', 'issued': '2020-03-20T21:53:14.197-04:00', 'valueQuantity': {'value': 2.7168, 'unit': '%', 'system': 'http://unitsofmeasure.org', 'code': '%'}}
# 673                                {'resourceType': 'Observation', 'id': '1555809', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '742-7', 'display': 'Monocytes [#/volume] in Blood by Automated count'}], 'text': 'Monocytes [#/volume] in Blood by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-20T21:53:14-04:00', 'issued': '2020-03-20T21:53:14.197-04:00', 'valueQuantity': {'value': 0.78465, 'unit': '10*3/uL', 'system': 'http://unitsofmeasure.org', 'code': '10*3/uL'}}
# 674                             {'resourceType': 'Observation', 'id': '1555808', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '731-0', 'display': 'Lymphocytes [#/volume] in Blood by Automated count'}], 'text': 'Lymphocytes [#/volume] in Blood by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-20T21:53:14-04:00', 'issued': '2020-03-20T21:53:14.197-04:00', 'valueQuantity': {'value': 1.1423, 'unit': '10*3/uL', 'system': 'http://unitsofmeasure.org', 'code': '10*3/uL'}}
# 675                                    {'resourceType': 'Observation', 'id': '1555801', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '777-3', 'display': 'Platelets [#/volume] in Blood by Automated count'}], 'text': 'Platelets [#/volume] in Blood by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-20T21:53:14-04:00', 'issued': '2020-03-20T21:53:14.197-04:00', 'valueQuantity': {'value': 116, 'unit': '10*3/uL', 'system': 'http://unitsofmeasure.org', 'code': '10*3/uL'}}
# 676                           {'resourceType': 'Observation', 'id': '1555800', 'meta': {'versionId': '1', 'lastUpdated': '2020-10-10T01:41:32.149+00:00', 'source': '#orszLs1yinxFCGZq'}, 'status': 'final', 'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/observation-category', 'code': 'laboratory', 'display': 'laboratory'}]}], 'code': {'coding': [{'system': 'http://loinc.org', 'code': '788-0', 'display': 'Erythrocyte distribution width [Ratio] by Automated count'}], 'text': 'Erythrocyte distribution width [Ratio] by Automated count'}, 'subject': {'reference': 'Patient/1555106'}, 'encounter': {'reference': 'Encounter/1555193'}, 'effectiveDateTime': '2020-03-20T21:53:14-04:00', 'issued': '2020-03-20T21:53:14.197-04:00', 'valueQuantity': {'value': 12.922, 'unit': '%', 'system': 'http://unitsofmeasure.org', 'code': '%'}}
#
#     Observation  Patient
# 0       1555734  1555106
# 1       1555771  1555106
# 2       1555770  1555106
# 3       1555528  1555106
# 4       1555769  1555106
# ..          ...      ...
# 672     1555806  1555106
# 673     1555809  1555106
# 674     1555808  1555106
# 675     1555801  1555106
# 676     1555800  1555106
#
# [677 rows x 3 columns]

# %%
pack\
.getPatients(['ddbf5561-4bfd-4434-89fb-344387ca945b'])\
.getDiagnosticReports()\
.summary
# .gatherSimplePaths(['id','subject','identifier'])
# Out:
# GET[Patient]> : 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# SEARCH[DiagnosticReport]> :   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# pack.getPatients(['4137ebc9d2d745fbcf7ab6ea86d626a6d97096a3384dc53d666c3611c16b8136']).getConditions()[:1].pretty

pack.getConditions(
	searchParams={
		"code":"J84",
	}
)
# .gatherSimplePaths(['subject'],columns=['data']).getResources().getMedicationRequests()
# .getPatients()
# Out:
# Empty Frame
# Columns: [data, Condition]
# Index: []
